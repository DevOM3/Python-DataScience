# %%
import pandas as pd 

df = pd.read_csv('data.csv')
df
# Out:
#           SYMBOL  SERIES         DATE1   PREV_CLOSE   OPEN_PRICE   HIGH_PRICE  \
# 0      20MICRONS      EQ   22-Jun-2020         31.3        32.20        33.70
# 1     21STCENMGM      EQ   22-Jun-2020         10.8        11.00        11.00
# 2     3IINFOTECH      EQ   22-Jun-2020          2.6         2.65         2.70
# 3        3MINDIA      EQ   22-Jun-2020      18593.3     18565.00     18699.00
# 4         5PAISA      EQ   22-Jun-2020        177.3       174.05       194.00
# ...          ...     ...           ...          ...          ...          ...
# 1981   ZODJRDMKJ      EQ   22-Jun-2020         24.3        24.00        25.90
# 1982        ZOTA      EQ   22-Jun-2020        141.7       144.35       154.45
# 1983       ZUARI      EQ   22-Jun-2020        117.3       115.00       115.00
# 1984   ZUARIGLOB      EQ   22-Jun-2020         61.2        61.20        62.25
# 1985   ZYDUSWELL      EQ   22-Jun-2020       1265.3      1272.00      1288.75
#
# ...

# %%
df.columns.to_list()
# Out:
# ['SYMBOL',
#  ' SERIES',
#  ' DATE1',
#  ' PREV_CLOSE',
#  ' OPEN_PRICE',
#  ' HIGH_PRICE',
#  ' LOW_PRICE',
#  ' LAST_PRICE',
#  ' CLOSE_PRICE',
#  ' AVG_PRICE',
#  ' TTL_TRD_QNTY',
#  ' TURNOVER_LACS',
#  ' NO_OF_TRADES',
#  ' DELIV_QTY',
#  ' DELIV_PER']

# %%
df[['SYMBOL', ' AVG_PRICE']]
symbol = df['SYMBOL']
avg = df[' DATE1']

# %%
import matplotlib.pyplot as plt

# %%
plt.title('TCS Stock Data Analysis')
plt.xlabel('SYMBOL')
plt.ylabel('DATE')
plt.plot(symbol, avg, label='Av. price per DATE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c8718e3d3e6b> in <module>
#       2 plt.xlabel('SYMBOL')
#       3 plt.ylabel('DATE')
# ----> 4 plt.plot(symbol, avg, label='Av. price per DATE')
#       5 plt.show()
#
# NameError: name 'symbol' is not defined
